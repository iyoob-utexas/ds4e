# %% [markdown]
# <a href="https://colab.research.google.com/github/iyoob-utexas/ds4e/blob/main/notebooks/c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![utexas_ds_orie_header.png](data:image/png;base64,...)

# %% [markdown]
# ![utexas_ds_orie_divider.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color='#475468'> Introduction:</font>

# %% [markdown]
# ![utexas_ds_orie_divider.png](data:image/png;base64,...)

# %% [markdown]
# DS is the hottest job with applications in healthcare, finance, oil/gas, retail, airlines, etc... but what are they really trying to solve?

# %% [markdown]
# ### What questions does Data Science help answer??

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Objective is that by the end of the semester, you should be able to market yourself as someone with Data Science skills...
#
# We are not going to teach all the details - instead we are going to learn on the fly - like learning to swim while in the water...
#
# Let's go over the syllabus...

# %% [markdown]
# ![utexas_ds_orie_divider_gray.png](data:image/png;base64,...)

# %% [markdown]
# ### Where is it applied?

# %% [markdown]
# Data Science is applied in every domain:
#
# 1. Healthcare (Watson)
# 2. Finance (Blackrock)
# 3. Transportation (Amazon)
# 4. Defense (DoD, Raytheon)
# 5. Space (Hypergiant)
# 6. IT (IBM)
# 7. Retail (Conversenow)
# 8. Airlines
# 9. Legal
# 10. Cyber
# 11. Auto
# 12. Real-estate
# 13. Pharma
# 14. Entertainment
# 15. E-commerce
# 16. Oil and gas
# 17. Multimedia (audio/video)
# 18. Agriculture
# ...

# %% [markdown]
# ### What's it like working as a Data Scientist?

# %% [markdown]
# A day in the life of a Data Scientist...
# - what is the question you are trying to answer?
# - what data is available?
# - iterate between business question and data available

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Where do you start?  with the data...

# %% [markdown]
# Sources of data:
# - Google trends
# - Google public data
# - IBM data exchange
# - AWS data registry
# - data.gov
# - World bank data
# - WHO data
# - Unicef open data
